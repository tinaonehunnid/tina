# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [10, 5]

# %%
df = pd.read_csv('./besitos_coordinates.csv', header=None)

# %%
df.columns = ['x', 'y']

# %%
df
# Out:
#               x          y
# 0     42.828125  44.671875
# 1     45.109375  46.625000
# 2     47.406250  48.578125
# 3     47.406250  52.390625
# 4     47.406250  56.156250
# ..          ...        ...
# 262  445.460938  17.390625
# 263  445.460938   0.000000
# 264  427.882812   0.000000
# 265  427.882812  17.390625
# 266  413.867188   0.000000
#
# [267 rows x 2 columns]

# %%
plt.plot(df['x'], df['y'])
